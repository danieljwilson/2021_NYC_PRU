# %%
import numpy as np
import pandas as pd

# %% [markdown]
# - [NYCgov Poverty Measure Data (2016)](https://data.cityofnewyork.us/City-Government/NYCgov-Poverty-Measure-Data-2016-/y9gu-cxxw)

# %%
df_2016 = pd.read_csv('../Data/NYCgov_Poverty_Measure_Data__2016_.csv')

# %%
df_2016.head()
# Out:
#    SERIALNO  SPORDER  PWGTP  WGTP  AGEP  CIT  REL  SCH  SCHG  SCHL  ...  \
# 0   1000006        1    103   103    26    1    0    1     0  20.0  ...
# 1   1000006        2    230   103    27    1   12    1     0  21.0  ...
# 2   1000014        1    106   106    56    2    0    1     0  16.0  ...
# 3   1000014        2    155   106    35    2    2    1     0  16.0  ...
# 4   1000020        1     50    50    36    4    0    1     0  21.0  ...
#
#    NYCgov_FICAtax  NYCgov_IncomeTax  NYCgov_Income  NYCgov_EITC  \
# 0     3622.782654       8554.465721   31314.387625       0.0000
# 1     3755.800442       8272.128682   32559.877677       0.0000
# 2     1233.287712       1033.539951   20927.520337       0.0000
# 3     1233.287712       1033.539951   20927.520337       0.0000
# 4      616.643856      -5780.983280   20861.643424    3627.3168
#
#    Off_Threshold  Off_Pov_Stat  NYCgov_Threshold  NYCgov_Pov_Stat  \
# 0        12486.0             2      15017.129826                2
# ...

# %%
df_2016.describe()
# Out:
#            SERIALNO       SPORDER         PWGTP          WGTP         AGEP  \
# count  6.864400e+04  68644.000000  68644.000000  68644.000000  68644.00000
# mean   7.667269e+05      2.304950    121.798715    113.828492     39.50488
# std    4.404749e+05      1.549919     90.829016     83.118195     22.73431
# min    3.900000e+01      1.000000     14.000000     14.000000      0.00000
# 25%    3.858370e+05      1.000000     64.000000     61.000000     22.00000
# 50%    7.689230e+05      2.000000     95.000000     88.000000     38.00000
# 75%    1.150590e+06      3.000000    152.000000    142.000000     57.00000
# max    1.521415e+06     20.000000   1746.000000   1746.000000     95.00000
#
#                 CIT           REL           SCH          SCHG          SCHL  \
# count  68644.000000  68644.000000  68644.000000  68644.000000  66404.000000
# mean       2.339942      2.365742      1.273280      2.345988     15.928830
# ...

# %% [markdown]
# # Profildescribe

# %%
from pandas_profiling import ProfileReport

# %%
profile = ProfileReport(df_2016, title='2016 Poverty Measure Data')

# %%
# Method to view in Jupyter
profito_fileo_notebook_iframe()

# %%
# Method to save as html
profile.to_file('pru_2016_eda_report.html')
# Out:
# /Users/djw/opt/miniconda3/envs/CIC/lib/python3.9/site-packages/pandas_profiling/profile_report.py:266: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Rename
